# %%
 # !pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain beautifulsoup4 langchain_chroma langgraph grandalf langchain sentence-transformers faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Implement a LangChain chat model that takes a user’s query about the weather forecast
# for a specific city and responds with a JSON object containing the city_name,
# forecast, temperature, and timestamp of the response

# %%
from langchain_openai import ChatOpenAI
import getpass

api_key = getpass.getpass("OpenAI Key:")
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=api_key
)
# Out:
# OpenAI Key:··········

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from datetime import datetime
llm = ChatOpenAI(model="gpt-4o-mini", api_key=api_key)
parser = StrOutputParser()
llmp = llm | parser

def get_weather_forecast(city_name):
    prompt = f"""
    You are a weather forecasting assistant. Please provide the current weather forecast for the city '{city_name}' in the following JSON format:
    {{
        "city_name": "{city_name}",
        "forecast": "<weather_description>",
        "temperature": "<temperature_in_Celsius>",
        "timestamp": "<current_timestamp>"
    }}
    """
    return llmp.invoke(prompt)



city = "New York"
weather_json = get_weather_forecast(city)
print(weather_json)
# Out:
# I don't have real-time data access to provide the current weather forecast. However, you can easily obtain this information from a weather API or a weather website. Once you have the data, you can format it in the requested JSON structure. Here's a template you can use:
#
# ```json
# {
#     "city_name": "New York",
#     "forecast": "Clear sky",
#     "temperature": "22",
#     "timestamp": "2023-10-05T12:00:00Z"
# }
# ```
#
# Make sure to replace the values with the actual weather data you retrieve.

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
llm = ChatOpenAI(model="gpt-4o-mini", api_key=api_key)
parser = StrOutputParser()
industry=input('enter the industry in which you are looking jobs for ')
sys_tem ='give me only available job positions for the specific industry with name : {industry} '
prompt_template= ChatPromptTemplate.from_messages([('system',sys_tem),''',('user',user_temp)'''])
class Job(BaseModel):
  job_title : str = Field(description="job title of the job")
  company : str = Field(description="name of the company")
  location : str = Field(description="location of the company")
  salary: str = Field(description="expected salary range")
  description: list[str] = Field(description="job description")

job_llm = llm.with_structured_output(Job)
llmf = prompt_template | job_llm
llmf.invoke({'industry':industry})
# Out:
# enter the industry in which you are looking jobs for datascience
# Job(job_title='Data Scientist', company='Tech Innovations', location='New York, NY', salary='$90,000 - $120,000', description=['Analyze large datasets to identify trends and insights.', 'Develop predictive models using machine learning techniques.', 'Collaborate with cross-functional teams to implement data-driven solutions.', 'Communicate findings to stakeholders through visualizations and reports.'])

# %% [markdown]
# Develop a tool in LangChain that calls an external API to retrieve current cryptocurrency prices based on the user's specified coin (e.g., Bitcoin, Ethereum).Implement the logic to generate the API call with the correct parameters and parse the response to extract coin_name, current_price, and price_change_percentage.

# %%
# from requests import Request, Session
# from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
# import json

# url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
# parameters = {
#   'start':'1',
#   'limit':'5000',
#   'convert':'USD'
# }
# headers = {
#   'Accepts': 'application/json',
#   'X-CMC_PRO_API_KEY': '13546c36-a192-4982-aa26-1e2253649c77',
# }

# session = Session()
# session.headers.update(headers)

# try:
#   response = session.get(url, params=parameters)
#   data = json.loads(response.text)
#   print(data)
# except (ConnectionError, Timeout, TooManyRedirects) as e:
#   print(e)
from langchain.tools import BaseTool
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langgraph.prebuilt import create_react_agent
import asyncio

llm = ChatOpenAI(model="gpt-4o-mini", api_key=api_key)
parser = StrOutputParser()
class CryptoPriceTool(BaseTool):
    name = "CryptoPriceTool"
    description = "Retrieve cryptocurrency prices using CoinMarketCap API."

    def _run(self, coin_name: str):
        url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
        parameters = {
            'start': '1',
            'limit': '5000',
            'convert': 'USD'
        }
        headers = {
            'Accepts': 'application/json',
            'X-CMC_PRO_API_KEY': '13546c36-a192-4982-aa26-1e2253649c77',
        }

        session = Session()
        session.headers.update(headers)

        try:
            response = session.get(url, params=parameters)
            data = json.loads(response.text)
            for coin in data['data']:
                if coin['name'].lower() == coin_name.lower() or coin['symbol'].lower() == coin_name.lower():
                    return {
                        'coin_name': coin['name'],
                        'current_price': coin['quote']['USD']['price'],
                        'price_change_percentage': coin['quote']['USD']['percent_change_24h']
                    }
            return f"{coin_name} not found in the top 5000 cryptocurrencies."

        except (ConnectionError, Timeout, TooManyRedirects) as e:
            return str(e)

crypto_tool = CryptoPriceTool()
llma = create_react_agent(llm, tools=[crypto_tool])
res = llma.invoke({"messages": "Can you retrieve the price for Ethereum??"})
res
# Out:
# {'messages': [HumanMessage(content='Can you retrieve the price for Ethereum??', id='f01a4f8c-5a3a-41f5-bc6d-b73bbd7dd71b'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_ThHnAAxiEA8lM11prq3MQZ2Y', 'function': {'arguments': '{"coin_name":"Ethereum"}', 'name': 'CryptoPriceTool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 56, 'total_tokens': 73}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_483d39d857', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ea385839-56a3-4540-87d1-bd69e43b29bc-0', tool_calls=[{'name': 'CryptoPriceTool', 'args': {'coin_name': 'Ethereum'}, 'id': 'call_ThHnAAxiEA8lM11prq3MQZ2Y', 'type': 'tool_call'}], usage_metadata={'input_tokens': 56, 'output_tokens': 17, 'total_tokens': 73}),
# ...

# %%
res['messages'][-1].content
# Out:
# 'The current price of Ethereum is approximately $2,283.74, with a price change of about 0.98%.'

# %%
pip install langchain langdetect requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=5189a1afe18de513e88854caefb623c2655f88ccaabe8e9dbf7f2d208cc25e41
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from langdetect import detect, DetectorFactory
import requests

# Ensures consistent language detection results
DetectorFactory.seed = 0

# Set up the translation function
def translate_text(text, source_language, target_language='en'):
    api_url = "https://api-free.deepl.com/v2/translate"  # Change to your API of choice
    api_key = 'a0784dc2-6818-4dfc-8760-15224798f8d3:fx'  # Replace with your API key

    params = {
        'auth_key': api_key,
        'text': text,
        'source_lang': source_language.upper(),
        'target_lang': target_language.upper()
    }

    response = requests.post(api_url, data=params)
    translated_text = response.json().get('translations', [{}])[0].get('text', '')

    return translated_text

# Set up a function that detects the language and translates it if necessary
def detect_and_translate(input_text):
    # Step 1: Detect the language
    detected_language = detect(input_text)

    # Step 2: If the detected language is not English, translate it
    if detected_language != 'en':
        translated_text = translate_text(input_text, detected_language)
        return {
            "source_language": detected_language,
            "translated_text": translated_text
        }
    else:
        return {
            "source_language": "en",
            "translated_text": input_text
        }

# Test the function
user_input = "Hola, ¿cómo estás?"
response = detect_and_translate(user_input)
print(response)
# Out:
# {'source_language': 'es', 'translated_text': 'Hello, how are you?'}
